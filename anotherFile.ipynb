# %%
import json
from dotenv import load_dotenv
import os
import base64
from requests import post, get

load_dotenv()
client_id = os.getenv("CLIENT_ID")
secret_id = os.getenv("SECRET_ID")

# %%
def retrieve_token():
    auth_string = f"{client_id}:{secret_id}"
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {"Authorization": "Basic " + auth_base64, "Content-Type": "application/x-www-form-urlencoded"}
    data = {"grant_type": "client_credentials"}
    result = post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]

    return token

# %%
retrieve_token()
# Out:
# 'BQCsiMPK5nuPor7gbqm26PFx04YCA9eOUnK5u5iU0mfTWxOGevluum3CTREbDgYBlVam_7ATG1UX4X424YbO-2bVlWFTEWNYBV3X9JWJaXB_dHsjDTM'

# %%
def search_for_id(artist_name, type, limit=20):
    url = "https://api.spotify.com/v1/search"
    query = f"?q={artist_name}&type={type}&limit={limit}"
    query_url = f"{url}{query}"

    token = retrieve_token()
    headers = {"Authorization": f"Bearer {token}"}
    result = get(query_url, headers=headers)

    json_result = json.loads(result.content)["artists"]["items"]
    if len(json_result) == 0:
        print("No artist with this name exists....")
        return None
    return json_result

# %%
search_list = search_for_id("fela", "artist")

# %%
print(search_list)
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CG9X521RDFWCuAhlo6QoR'}, 'followers': {'href': None, 'total': 555352}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/5CG9X521RDFWCuAhlo6QoR', 'id': '5CG9X521RDFWCuAhlo6QoR', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe8670e361382ef18bbe5b93d', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e8670e361382ef18bbe5b93d', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e8670e361382ef18bbe5b93d', 'width': 160}], 'name': 'Fela Kuti', 'popularity': 48, 'type': 'artist', 'uri': 'spotify:artist:5CG9X521RDFWCuAhlo6QoR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5PeZ1m5v30OjVgzBz6PgHa'}, 'followers': {'href': None, 'total': 26006}, 'genres': ['anime hardstyle'], 'href': 'https://api.spotify.com/v1/artists/5PeZ1m5v30OjVgzBz6PgHa', 'id': '5PeZ1m5v30OjVgzBz6PgHa', 'images': [{'he
# ...

# %%
from pprint import pprint

# %%
import pandas as pd

# %%
pprint([{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CG9X521RDFWCuAhlo6QoR'}, 'followers': {'href': None, 'total': 555352}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/5CG9X521RDFWCuAhlo6QoR', 'id': '5CG9X521RDFWCuAhlo6QoR', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe8670e361382ef18bbe5b93d', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e8670e361382ef18bbe5b93d', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e8670e361382ef18bbe5b93d', 'width': 160}], 'name': 'Fela Kuti', 'popularity': 48, 'type': 'artist', 'uri': 'spotify:artist:5CG9X521RDFWCuAhlo6QoR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5PeZ1m5v30OjVgzBz6PgHa'}, 'followers': {'href': None, 'total': 26006}, 'genres': ['anime hardstyle'], 'href': 'https://api.spotify.com/v1/artists/5PeZ1m5v30OjVgzBz6PgHa', 'id': '5PeZ1m5v30OjVgzBz6PgHa', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebf2ad76ed7ebb0d3499fd357a', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174f2ad76ed7ebb0d3499fd357a', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178f2ad76ed7ebb0d3499fd357a', 'width': 160}], 'name': 'Felax', 'popularity': 32, 'type': 'artist', 'uri': 'spotify:artist:5PeZ1m5v30OjVgzBz6PgHa'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgrtA0dlnVpWB6zjpXrRb'}, 'followers': {'href': None, 'total': 65160}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/6kgrtA0dlnVpWB6zjpXrRb', 'id': '6kgrtA0dlnVpWB6zjpXrRb', 'images': [{'height': 1515, 'url': 'https://i.scdn.co/image/09c74ee42b16d3d0f24d9d5611bed7b1df105b71', 'width': 1000}, {'height': 970, 'url': 'https://i.scdn.co/image/a0936e190d018d702603fca477732aac05faa863', 'width': 640}, {'height': 303, 'url': 'https://i.scdn.co/image/2607d7ce1f655b42722ec2b8f4e032276cc07524', 'width': 200}, {'height': 97, 'url': 'https://i.scdn.co/image/8b2b34048a56a6e6c7da64d0ccd1e98c2979c7e3', 'width': 64}], 'name': 'Femi Kuti', 'popularity': 34, 'type': 'artist', 'uri': 'spotify:artist:6kgrtA0dlnVpWB6zjpXrRb'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xWchnMNwQTcw543ZAMDcb'}, 'followers': {'href': None, 'total': 110}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/6xWchnMNwQTcw543ZAMDcb', 'id': '6xWchnMNwQTcw543ZAMDcb', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb36a1ee26aa866457a83695f7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517436a1ee26aa866457a83695f7', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17836a1ee26aa866457a83695f7', 'width': 160}], 'name': 'Feladehusla', 'popularity': 21, 'type': 'artist', 'uri': 'spotify:artist:6xWchnMNwQTcw543ZAMDcb'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/755pQSGUy6rtPrUCbnJTvi'}, 'followers': {'href': None, 'total': 118347}, 'genres': ['afrobeat', 'afropop'], 'href': 'https://api.spotify.com/v1/artists/755pQSGUy6rtPrUCbnJTvi', 'id': '755pQSGUy6rtPrUCbnJTvi', 'images': [{'height': 753, 'url': 'https://i.scdn.co/image/683b46e963c1db53727703a1aff9a707b0b0ecc1', 'width': 600}, {'height': 251, 'url': 'https://i.scdn.co/image/34d39ce677a551ab9bb1ac6ea90ba29931dd2f14', 'width': 200}, {'height': 80, 'url': 'https://i.scdn.co/image/62fed4c1838ab9b7ec56dbae82d36b7342ac9037', 'width': 64}], 'name': 'William Onyeabor', 'popularity': 40, 'type': 'artist', 'uri': 'spotify:artist:755pQSGUy6rtPrUCbnJTvi'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nzfP8y591BGa4K4ImEtWm'}, 'followers': {'href': None, 'total': 538}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/6nzfP8y591BGa4K4ImEtWm', 'id': '6nzfP8y591BGa4K4ImEtWm', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273a82815f7014542e1eec78710', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02a82815f7014542e1eec78710', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851a82815f7014542e1eec78710', 'width': 64}], 'name': 'Fela Sowande', 'popularity': 20, 'type': 'artist', 'uri': 'spotify:artist:6nzfP8y591BGa4K4ImEtWm'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2OybaXOvLskhpoRmbX5qjF'}, 'followers': {'href': None, 'total': 14259}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/2OybaXOvLskhpoRmbX5qjF', 'id': '2OybaXOvLskhpoRmbX5qjF', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273552c512c414561dcf60e8ff8', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02552c512c414561dcf60e8ff8', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851552c512c414561dcf60e8ff8', 'width': 64}], 'name': 'Fela 2', 'popularity': 17, 'type': 'artist', 'uri': 'spotify:artist:2OybaXOvLskhpoRmbX5qjF'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vYvTD3vLMEQOQS2phjwkN'}, 'followers': {'href': None, 'total': 7253}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3vYvTD3vLMEQOQS2phjwkN', 'id': '3vYvTD3vLMEQOQS2phjwkN', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe83736ee78fb3e740be5c596', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e83736ee78fb3e740be5c596', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e83736ee78fb3e740be5c596', 'width': 160}], 'name': 'Fela Domínguez', 'popularity': 28, 'type': 'artist', 'uri': 'spotify:artist:3vYvTD3vLMEQOQS2phjwkN'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JpZEemWmunccsrHXFUOgi'}, 'followers': {'href': None, 'total': 127955}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/6JpZEemWmunccsrHXFUOgi', 'id': '6JpZEemWmunccsrHXFUOgi', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb141e61501f5086d23386eb9f', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174141e61501f5086d23386eb9f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178141e61501f5086d23386eb9f', 'width': 160}], 'name': 'Tony Allen', 'popularity': 43, 'type': 'artist', 'uri': 'spotify:artist:6JpZEemWmunccsrHXFUOgi'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/43Nia3hYngairIVoe5NN1K'}, 'followers': {'href': None, 'total': 182}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/43Nia3hYngairIVoe5NN1K', 'id': '43Nia3hYngairIVoe5NN1K', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb042dfbba4d396c335fd39fd4', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174042dfbba4d396c335fd39fd4', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178042dfbba4d396c335fd39fd4', 'width': 160}], 'name': "Fe'la Iniko", 'popularity': 7, 'type': 'artist', 'uri': 'spotify:artist:43Nia3hYngairIVoe5NN1K'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2KGF6IKZfVGCKfyqcNVGfh'}, 'followers': {'href': None, 'total': 72634}, 'genres': ['afrobeat', 'latin afrobeat', 'world'], 'href': 'https://api.spotify.com/v1/artists/2KGF6IKZfVGCKfyqcNVGfh', 'id': '2KGF6IKZfVGCKfyqcNVGfh', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebfcfde8f058c7a7e42facfe09', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174fcfde8f058c7a7e42facfe09', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178fcfde8f058c7a7e42facfe09', 'width': 160}], 'name': 'Antibalas', 'popularity': 34, 'type': 'artist', 'uri': 'spotify:artist:2KGF6IKZfVGCKfyqcNVGfh'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IYSQrJKkRaNmPk0oOxbwZ'}, 'followers': {'href': None, 'total': 78}, 'genres': ['instrumental lullaby'], 'href': 'https://api.spotify.com/v1/artists/2IYSQrJKkRaNmPk0oOxbwZ', 'id': '2IYSQrJKkRaNmPk0oOxbwZ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba6742335b9b38b1995b5ad9e', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a6742335b9b38b1995b5ad9e', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a6742335b9b38b1995b5ad9e', 'width': 160}], 'name': 'Lindsay Felan', 'popularity': 38, 'type': 'artist', 'uri': 'spotify:artist:2IYSQrJKkRaNmPk0oOxbwZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eatcjNWvGuDEPNnjgPNn1'}, 'followers': {'href': None, 'total': 81252}, 'genres': ['afrobeat', 'afropop', 'griot', 'juju'], 'href': 'https://api.spotify.com/v1/artists/0eatcjNWvGuDEPNnjgPNn1', 'id': '0eatcjNWvGuDEPNnjgPNn1', 'images': [{'height': 1011, 'url': 'https://i.scdn.co/image/51a79a6ad1098ff8ed70600c1952f33b89e0660a', 'width': 1000}, {'height': 647, 'url': 'https://i.scdn.co/image/9a7dde9928b6913d5f87d2fb347c20a2e78c3deb', 'width': 640}, {'height': 202, 'url': 'https://i.scdn.co/image/ce414f2f4de571bc1165c5695171cfe5b2a7062a', 'width': 200}, {'height': 65, 'url': 'https://i.scdn.co/image/5ad395d474360f0088835574beb9bcb6ee673853', 'width': 64}], 'name': 'King Sunny Ade', 'popularity': 39, 'type': 'artist', 'uri': 'spotify:artist:0eatcjNWvGuDEPNnjgPNn1'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jysZOxoP55I6WDlApdbit'}, 'followers': {'href': None, 'total': 62}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0jysZOxoP55I6WDlApdbit', 'id': '0jysZOxoP55I6WDlApdbit', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebda6e53acae90feb539829a73', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174da6e53acae90feb539829a73', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178da6e53acae90feb539829a73', 'width': 160}], 'name': 'Felavish', 'popularity': 6, 'type': 'artist', 'uri': 'spotify:artist:0jysZOxoP55I6WDlApdbit'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GQur7dDvAWhKT9u9YwBJZ'}, 'followers': {'href': None, 'total': 46709}, 'genres': ['afrobeat', 'afropop'], 'href': 'https://api.spotify.com/v1/artists/1GQur7dDvAWhKT9u9YwBJZ', 'id': '1GQur7dDvAWhKT9u9YwBJZ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb2decf6bb084874a8b6ad4985', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051742decf6bb084874a8b6ad4985', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1782decf6bb084874a8b6ad4985', 'width': 160}], 'name': 'Seun Kuti', 'popularity': 44, 'type': 'artist', 'uri': 'spotify:artist:1GQur7dDvAWhKT9u9YwBJZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/470XxGVPz2S5Qnu75fZemK'}, 'followers': {'href': None, 'total': 545}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/470XxGVPz2S5Qnu75fZemK', 'id': '470XxGVPz2S5Qnu75fZemK', 'images': [], 'name': 'Fela Ransome-Kuti and the Africa ’70', 'popularity': 6, 'type': 'artist', 'uri': 'spotify:artist:470XxGVPz2S5Qnu75fZemK'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3mNygoyrEKLgo6sx0MzwOL'}, 'followers': {'href': None, 'total': 263066}, 'genres': ['afropop', 'desert blues', 'malian blues', 'mande pop', 'world'], 'href': 'https://api.spotify.com/v1/artists/3mNygoyrEKLgo6sx0MzwOL', 'id': '3mNygoyrEKLgo6sx0MzwOL', 'images': [{'height': 563, 'url': 'https://i.scdn.co/image/0d183847042a7c6e27c04f21fbe2273d63d03e50', 'width': 1000}, {'height': 360, 'url': 'https://i.scdn.co/image/410e634c2945b0782700c4485f9ed77f9c9afe37', 'width': 640}, {'height': 113, 'url': 'https://i.scdn.co/image/0178ad8bf5b619b94872233280a3fcaff2dbcd5d', 'width': 200}, {'height': 36, 'url': 'https://i.scdn.co/image/ae9570d24ef433088bee1a17f6a877fd52d88c79', 'width': 64}], 'name': 'Ali Farka Touré', 'popularity': 47, 'type': 'artist', 'uri': 'spotify:artist:3mNygoyrEKLgo6sx0MzwOL'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2J55k7Jd101WcYqeWUnqYG'}, 'followers': {'href': None, 'total': 189}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/2J55k7Jd101WcYqeWUnqYG', 'id': '2J55k7Jd101WcYqeWUnqYG', 'images': [], 'name': 'FELA! Original Broadway Cast', 'popularity': 6, 'type': 'artist', 'uri': 'spotify:artist:2J55k7Jd101WcYqeWUnqYG'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7HGFXtBhRq3g1Ma3nH4Rgv'}, 'followers': {'href': None, 'total': 233244}, 'genres': ['afrobeat', 'afropop', 'ethio-jazz', 'world'], 'href': 'https://api.spotify.com/v1/artists/7HGFXtBhRq3g1Ma3nH4Rgv', 'id': '7HGFXtBhRq3g1Ma3nH4Rgv', 'images': [{'height': 1498, 'url': 'https://i.scdn.co/image/e7566bc77a7e251fc68da6322737af51ca2f04d7', 'width': 1000}, {'height': 959, 'url': 'https://i.scdn.co/image/20a9b2d98169475f1d2f7c4fade56b06b74528f1', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/b31c07d27c5adf3cd74c87c1364d2e23c271db7d', 'width': 200}, {'height': 96, 'url': 'https://i.scdn.co/image/3a6ce10ba3dbc5be483486bd386f266a6b185c47', 'width': 64}], 'name': 'Mulatu Astatke', 'popularity': 53, 'type': 'artist', 'uri': 'spotify:artist:7HGFXtBhRq3g1Ma3nH4Rgv'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3iWYbaIaa074f7JrE8bm34'}, 'followers': {'href': None, 'total': 94}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3iWYbaIaa074f7JrE8bm34', 'id': '3iWYbaIaa074f7JrE8bm34', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb09f71edb97289b57d72ddee0', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517409f71edb97289b57d72ddee0', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17809f71edb97289b57d72ddee0', 'width': 160}], 'name': 'Fela', 'popularity': 10, 'type': 'artist', 'uri': 'spotify:artist:3iWYbaIaa074f7JrE8bm34'}]
)
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CG9X521RDFWCuAhlo6QoR'},
#   'followers': {'href': None, 'total': 555352},
#   'genres': ['afrobeat', 'afropop', 'world'],
#   'href': 'https://api.spotify.com/v1/artists/5CG9X521RDFWCuAhlo6QoR',
#   'id': '5CG9X521RDFWCuAhlo6QoR',
#   'images': [{'height': 640,
#               'url': 'https://i.scdn.co/image/ab6761610000e5ebe8670e361382ef18bbe5b93d',
#               'width': 640},
#              {'height': 320,
#               'url': 'https://i.scdn.co/image/ab67616100005174e8670e361382ef18bbe5b93d',
#               'width': 320},
#              {'height': 160,
#               'url': 'https://i.scdn.co/image/ab6761610000f178e8670e361382ef18bbe5b93d',
#               'width': 160}],
#   'name': 'Fela Kuti',
#   'popularity': 48,
#   'type': 'artist',
#   'uri': 'spotify:artist:5CG9X521RDFWCuAhlo6QoR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5PeZ1m5v30OjVgzBz6PgHa'},
# ...

# %%
api = {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CG9X521RDFWCuAhlo6QoR'}, 'followers': {'href': None, 'total': 555352}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/5CG9X521RDFWCuAhlo6QoR', 'id': '5CG9X521RDFWCuAhlo6QoR', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe8670e361382ef18bbe5b93d', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e8670e361382ef18bbe5b93d', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e8670e361382ef18bbe5b93d', 'width': 160}], 'name': 'Fela Kuti', 'popularity': 48, 'type': 'artist', 'uri': 'spotify:artist:5CG9X521RDFWCuAhlo6QoR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5PeZ1m5v30OjVgzBz6PgHa'}, 'followers': {'href': None, 'total': 26006}, 'genres': ['anime hardstyle'], 'href': 'https://api.spotify.com/v1/artists/5PeZ1m5v30OjVgzBz6PgHa', 'id': '5PeZ1m5v30OjVgzBz6PgHa', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebf2ad76ed7ebb0d3499fd357a', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174f2ad76ed7ebb0d3499fd357a', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178f2ad76ed7ebb0d3499fd357a', 'width': 160}], 'name': 'Felax', 'popularity': 32, 'type': 'artist', 'uri': 'spotify:artist:5PeZ1m5v30OjVgzBz6PgHa'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgrtA0dlnVpWB6zjpXrRb'}, 'followers': {'href': None, 'total': 65160}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/6kgrtA0dlnVpWB6zjpXrRb', 'id': '6kgrtA0dlnVpWB6zjpXrRb', 'images': [{'height': 1515, 'url': 'https://i.scdn.co/image/09c74ee42b16d3d0f24d9d5611bed7b1df105b71', 'width': 1000}, {'height': 970, 'url': 'https://i.scdn.co/image/a0936e190d018d702603fca477732aac05faa863', 'width': 640}, {'height': 303, 'url': 'https://i.scdn.co/image/2607d7ce1f655b42722ec2b8f4e032276cc07524', 'width': 200}, {'height': 97, 'url': 'https://i.scdn.co/image/8b2b34048a56a6e6c7da64d0ccd1e98c2979c7e3', 'width': 64}], 'name': 'Femi Kuti', 'popularity': 34, 'type': 'artist', 'uri': 'spotify:artist:6kgrtA0dlnVpWB6zjpXrRb'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xWchnMNwQTcw543ZAMDcb'}, 'followers': {'href': None, 'total': 110}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/6xWchnMNwQTcw543ZAMDcb', 'id': '6xWchnMNwQTcw543ZAMDcb', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb36a1ee26aa866457a83695f7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517436a1ee26aa866457a83695f7', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17836a1ee26aa866457a83695f7', 'width': 160}], 'name': 'Feladehusla', 'popularity': 21, 'type': 'artist', 'uri': 'spotify:artist:6xWchnMNwQTcw543ZAMDcb'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/755pQSGUy6rtPrUCbnJTvi'}, 'followers': {'href': None, 'total': 118347}, 'genres': ['afrobeat', 'afropop'], 'href': 'https://api.spotify.com/v1/artists/755pQSGUy6rtPrUCbnJTvi', 'id': '755pQSGUy6rtPrUCbnJTvi', 'images': [{'height': 753, 'url': 'https://i.scdn.co/image/683b46e963c1db53727703a1aff9a707b0b0ecc1', 'width': 600}, {'height': 251, 'url': 'https://i.scdn.co/image/34d39ce677a551ab9bb1ac6ea90ba29931dd2f14', 'width': 200}, {'height': 80, 'url': 'https://i.scdn.co/image/62fed4c1838ab9b7ec56dbae82d36b7342ac9037', 'width': 64}], 'name': 'William Onyeabor', 'popularity': 40, 'type': 'artist', 'uri': 'spotify:artist:755pQSGUy6rtPrUCbnJTvi'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nzfP8y591BGa4K4ImEtWm'}, 'followers': {'href': None, 'total': 538}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/6nzfP8y591BGa4K4ImEtWm', 'id': '6nzfP8y591BGa4K4ImEtWm', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273a82815f7014542e1eec78710', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02a82815f7014542e1eec78710', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851a82815f7014542e1eec78710', 'width': 64}], 'name': 'Fela Sowande', 'popularity': 20, 'type': 'artist', 'uri': 'spotify:artist:6nzfP8y591BGa4K4ImEtWm'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2OybaXOvLskhpoRmbX5qjF'}, 'followers': {'href': None, 'total': 14259}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/2OybaXOvLskhpoRmbX5qjF', 'id': '2OybaXOvLskhpoRmbX5qjF', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273552c512c414561dcf60e8ff8', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02552c512c414561dcf60e8ff8', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851552c512c414561dcf60e8ff8', 'width': 64}], 'name': 'Fela 2', 'popularity': 17, 'type': 'artist', 'uri': 'spotify:artist:2OybaXOvLskhpoRmbX5qjF'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vYvTD3vLMEQOQS2phjwkN'}, 'followers': {'href': None, 'total': 7253}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3vYvTD3vLMEQOQS2phjwkN', 'id': '3vYvTD3vLMEQOQS2phjwkN', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe83736ee78fb3e740be5c596', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e83736ee78fb3e740be5c596', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e83736ee78fb3e740be5c596', 'width': 160}], 'name': 'Fela Domínguez', 'popularity': 28, 'type': 'artist', 'uri': 'spotify:artist:3vYvTD3vLMEQOQS2phjwkN'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JpZEemWmunccsrHXFUOgi'}, 'followers': {'href': None, 'total': 127955}, 'genres': ['afrobeat', 'afropop', 'world'], 'href': 'https://api.spotify.com/v1/artists/6JpZEemWmunccsrHXFUOgi', 'id': '6JpZEemWmunccsrHXFUOgi', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb141e61501f5086d23386eb9f', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174141e61501f5086d23386eb9f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178141e61501f5086d23386eb9f', 'width': 160}], 'name': 'Tony Allen', 'popularity': 43, 'type': 'artist', 'uri': 'spotify:artist:6JpZEemWmunccsrHXFUOgi'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/43Nia3hYngairIVoe5NN1K'}, 'followers': {'href': None, 'total': 182}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/43Nia3hYngairIVoe5NN1K', 'id': '43Nia3hYngairIVoe5NN1K', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb042dfbba4d396c335fd39fd4', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174042dfbba4d396c335fd39fd4', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178042dfbba4d396c335fd39fd4', 'width': 160}], 'name': "Fe'la Iniko", 'popularity': 7, 'type': 'artist', 'uri': 'spotify:artist:43Nia3hYngairIVoe5NN1K'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2KGF6IKZfVGCKfyqcNVGfh'}, 'followers': {'href': None, 'total': 72634}, 'genres': ['afrobeat', 'latin afrobeat', 'world'], 'href': 'https://api.spotify.com/v1/artists/2KGF6IKZfVGCKfyqcNVGfh', 'id': '2KGF6IKZfVGCKfyqcNVGfh', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebfcfde8f058c7a7e42facfe09', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174fcfde8f058c7a7e42facfe09', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178fcfde8f058c7a7e42facfe09', 'width': 160}], 'name': 'Antibalas', 'popularity': 34, 'type': 'artist', 'uri': 'spotify:artist:2KGF6IKZfVGCKfyqcNVGfh'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IYSQrJKkRaNmPk0oOxbwZ'}, 'followers': {'href': None, 'total': 78}, 'genres': ['instrumental lullaby'], 'href': 'https://api.spotify.com/v1/artists/2IYSQrJKkRaNmPk0oOxbwZ', 'id': '2IYSQrJKkRaNmPk0oOxbwZ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba6742335b9b38b1995b5ad9e', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a6742335b9b38b1995b5ad9e', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a6742335b9b38b1995b5ad9e', 'width': 160}], 'name': 'Lindsay Felan', 'popularity': 38, 'type': 'artist', 'uri': 'spotify:artist:2IYSQrJKkRaNmPk0oOxbwZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eatcjNWvGuDEPNnjgPNn1'}, 'followers': {'href': None, 'total': 81252}, 'genres': ['afrobeat', 'afropop', 'griot', 'juju'], 'href': 'https://api.spotify.com/v1/artists/0eatcjNWvGuDEPNnjgPNn1', 'id': '0eatcjNWvGuDEPNnjgPNn1', 'images': [{'height': 1011, 'url': 'https://i.scdn.co/image/51a79a6ad1098ff8ed70600c1952f33b89e0660a', 'width': 1000}, {'height': 647, 'url': 'https://i.scdn.co/image/9a7dde9928b6913d5f87d2fb347c20a2e78c3deb', 'width': 640}, {'height': 202, 'url': 'https://i.scdn.co/image/ce414f2f4de571bc1165c5695171cfe5b2a7062a', 'width': 200}, {'height': 65, 'url': 'https://i.scdn.co/image/5ad395d474360f0088835574beb9bcb6ee673853', 'width': 64}], 'name': 'King Sunny Ade', 'popularity': 39, 'type': 'artist', 'uri': 'spotify:artist:0eatcjNWvGuDEPNnjgPNn1'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jysZOxoP55I6WDlApdbit'}, 'followers': {'href': None, 'total': 62}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0jysZOxoP55I6WDlApdbit', 'id': '0jysZOxoP55I6WDlApdbit', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebda6e53acae90feb539829a73', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174da6e53acae90feb539829a73', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178da6e53acae90feb539829a73', 'width': 160}], 'name': 'Felavish', 'popularity': 6, 'type': 'artist', 'uri': 'spotify:artist:0jysZOxoP55I6WDlApdbit'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GQur7dDvAWhKT9u9YwBJZ'}, 'followers': {'href': None, 'total': 46709}, 'genres': ['afrobeat', 'afropop'], 'href': 'https://api.spotify.com/v1/artists/1GQur7dDvAWhKT9u9YwBJZ', 'id': '1GQur7dDvAWhKT9u9YwBJZ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb2decf6bb084874a8b6ad4985', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051742decf6bb084874a8b6ad4985', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1782decf6bb084874a8b6ad4985', 'width': 160}], 'name': 'Seun Kuti', 'popularity': 44, 'type': 'artist', 'uri': 'spotify:artist:1GQur7dDvAWhKT9u9YwBJZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/470XxGVPz2S5Qnu75fZemK'}, 'followers': {'href': None, 'total': 545}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/470XxGVPz2S5Qnu75fZemK', 'id': '470XxGVPz2S5Qnu75fZemK', 'images': [], 'name': 'Fela Ransome-Kuti and the Africa ’70', 'popularity': 6, 'type': 'artist', 'uri': 'spotify:artist:470XxGVPz2S5Qnu75fZemK'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3mNygoyrEKLgo6sx0MzwOL'}, 'followers': {'href': None, 'total': 263066}, 'genres': ['afropop', 'desert blues', 'malian blues', 'mande pop', 'world'], 'href': 'https://api.spotify.com/v1/artists/3mNygoyrEKLgo6sx0MzwOL', 'id': '3mNygoyrEKLgo6sx0MzwOL', 'images': [{'height': 563, 'url': 'https://i.scdn.co/image/0d183847042a7c6e27c04f21fbe2273d63d03e50', 'width': 1000}, {'height': 360, 'url': 'https://i.scdn.co/image/410e634c2945b0782700c4485f9ed77f9c9afe37', 'width': 640}, {'height': 113, 'url': 'https://i.scdn.co/image/0178ad8bf5b619b94872233280a3fcaff2dbcd5d', 'width': 200}, {'height': 36, 'url': 'https://i.scdn.co/image/ae9570d24ef433088bee1a17f6a877fd52d88c79', 'width': 64}], 'name': 'Ali Farka Touré', 'popularity': 47, 'type': 'artist', 'uri': 'spotify:artist:3mNygoyrEKLgo6sx0MzwOL'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2J55k7Jd101WcYqeWUnqYG'}, 'followers': {'href': None, 'total': 189}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/2J55k7Jd101WcYqeWUnqYG', 'id': '2J55k7Jd101WcYqeWUnqYG', 'images': [], 'name': 'FELA! Original Broadway Cast', 'popularity': 6, 'type': 'artist', 'uri': 'spotify:artist:2J55k7Jd101WcYqeWUnqYG'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7HGFXtBhRq3g1Ma3nH4Rgv'}, 'followers': {'href': None, 'total': 233244}, 'genres': ['afrobeat', 'afropop', 'ethio-jazz', 'world'], 'href': 'https://api.spotify.com/v1/artists/7HGFXtBhRq3g1Ma3nH4Rgv', 'id': '7HGFXtBhRq3g1Ma3nH4Rgv', 'images': [{'height': 1498, 'url': 'https://i.scdn.co/image/e7566bc77a7e251fc68da6322737af51ca2f04d7', 'width': 1000}, {'height': 959, 'url': 'https://i.scdn.co/image/20a9b2d98169475f1d2f7c4fade56b06b74528f1', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/b31c07d27c5adf3cd74c87c1364d2e23c271db7d', 'width': 200}, {'height': 96, 'url': 'https://i.scdn.co/image/3a6ce10ba3dbc5be483486bd386f266a6b185c47', 'width': 64}], 'name': 'Mulatu Astatke', 'popularity': 53, 'type': 'artist', 'uri': 'spotify:artist:7HGFXtBhRq3g1Ma3nH4Rgv'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3iWYbaIaa074f7JrE8bm34'}, 'followers': {'href': None, 'total': 94}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3iWYbaIaa074f7JrE8bm34', 'id': '3iWYbaIaa074f7JrE8bm34', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb09f71edb97289b57d72ddee0', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517409f71edb97289b57d72ddee0', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17809f71edb97289b57d72ddee0', 'width': 160}], 'name': 'Fela', 'popularity': 10, 'type': 'artist', 'uri': 'spotify:artist:3iWYbaIaa074f7JrE8bm34'}

# %%
pd.DataFrame(api)
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/5...
# 1   {'spotify': 'https://open.spotify.com/artist/5...
# 2   {'spotify': 'https://open.spotify.com/artist/6...
# 3   {'spotify': 'https://open.spotify.com/artist/6...
# 4   {'spotify': 'https://open.spotify.com/artist/7...
# 5   {'spotify': 'https://open.spotify.com/artist/6...
# 6   {'spotify': 'https://open.spotify.com/artist/2...
# 7   {'spotify': 'https://open.spotify.com/artist/3...
# 8   {'spotify': 'https://open.spotify.com/artist/6...
# 9   {'spotify': 'https://open.spotify.com/artist/4...
# 10  {'spotify': 'https://open.spotify.com/artist/2...
# 11  {'spotify': 'https://open.spotify.com/artist/2...
# 12  {'spotify': 'https://open.spotify.com/artist/0...
# 13  {'spotify': 'https://open.spotify.com/artist/0...
# 14  {'spotify': 'https://open.spotify.com/artist/1...
# 15  {'spotify': 'https://open.spotify.com/artist/4...
# ...

# %%
api.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 api.keys()
#
# AttributeError: 'tuple' object has no attribute 'keys'
